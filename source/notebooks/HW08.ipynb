# %% [markdown]
# # HW8, Practice with databases and pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 1. sqlite3 databases
#
# ### i. Why, in the examples you saw, were all interactions with databases contained within codeblocks begining with:
#
#     with sqlite3.connect(database) as conn:

# %% [raw]
# This context manager ensures that the database connection is closed as soon as the block of code finishes executing, helping ensure atomicity of all transations.

# %% [markdown]
# ii. What statement allows you to read data from the database?

# %% [raw]
# conn.execute("""SELECT ... from ...""")
# pandas.read_sql(sql_string, conn)

# %% [markdown]
# iii. What does the `JOIN` clause do?

# %% [raw]
# JOIN takes two tables and of their Cartesian product returns just the rows with fields that satisfy the JOIN condition. By default, JOIN in SQLite performs an inner (intersection) join.

# %% [markdown]
# iv. What does the `WHERE` clause do?

# %% [raw]
# WHERE filters the pre-aggregate result records according to one or more conditions involving fields of the one or more tables selected.

# %% [markdown]
# v. Why did we choose to explore sqlite3?

# %% [raw]
# sqlite3 has standard Python libraries, is very portable because it is a file format, and is very commonly used as an embedded relational database in many applications.

# %% [markdown]
# ## 2. Pandas
#
# ### i. Can I add two Pandas databases that do not have the same column names and row indices?

# %% [raw]
# Yes -- Pandas will union together the column and row sets, but will produce NaN or None values (if not overridden) where they don't match between the dataframes.

# %% [markdown]
# ### ii. Why is it useful to have the add, sub, mul, etc. methods for Pandas DataFrames, when +, -, \*, etc. can also perform this arithmetic?

# %% [raw]
# The add, sub, mul, etc. methods allow for additional arguments (such as specifying the fill value) which are not available when using standard Python operators.

# %% [markdown]
# ### iii. By default, are actions performed over indices or columns? Give an example of default behavior.

# %% [raw]
# Over indices. For example,

# %%
df1 = pd.DataFrame(np.arange(20).reshape(4,5),index=np.arange(4),columns=list('abcde'))
df2 = pd.DataFrame(np.arange(12).reshape(3,4),index=np.arange(3)+1,columns=list('abcd'))

df1.drop(3)
# Out:
#     a   b   c   d   e
# 0   0   1   2   3   4
# 1   5   6   7   8   9
# 2  10  11  12  13  14

# %% [markdown]
# ### iv. How do I quickly get a summary of statistics about my dataframe?

# %%
df1.describe()
# Out:
#                a          b          c          d          e
# count   4.000000   4.000000   4.000000   4.000000   4.000000
# mean    7.500000   8.500000   9.500000  10.500000  11.500000
# std     6.454972   6.454972   6.454972   6.454972   6.454972
# min     0.000000   1.000000   2.000000   3.000000   4.000000
# 25%     3.750000   4.750000   5.750000   6.750000   7.750000
# 50%     7.500000   8.500000   9.500000  10.500000  11.500000
# 75%    11.250000  12.250000  13.250000  14.250000  15.250000
# max    15.000000  16.000000  17.000000  18.000000  19.000000

# %% [markdown]
# ### v. Pandas has a number of methods allows different file types to be read in. Can it handle comment lines? Header or lack there-of?

# %%
births = pd.read_csv('examples/births.csv', comment='#')
births
# Out:
#        year  month   day gender  births
# 0      1969      1   1.0      F    4046
# 1      1969      1   1.0      M    4440
# 2      1969      1   2.0      F    4454
# 3      1969      1   2.0      M    4548
# 4      1969      1   3.0      F    4548
# 5      1969      1   3.0      M    4994
# 6      1969      1   4.0      F    4440
# 7      1969      1   4.0      M    4520
# 8      1969      1   5.0      F    4192
# 9      1969      1   5.0      M    4198
# 10     1969      1   6.0      F    4710
# 11     1969      1   6.0      M    4850
# 12     1969      1   7.0      F    4646
# 13     1969      1   7.0      M    5092
# 14     1969      1   8.0      F    4800
# 15     1969      1   8.0      M    4934
# 16     1969      1   9.0      F    4592
# 17     1969      1   9.0      M    4842
# 18     1969      1  10.0      F    4852
# 19     1969      1  10.0      M    5190
# 20     1969      1  11.0      F    4580
# 21     1969      1  11.0      M    4598
# ...

# %%
births.pivot_table(values='births',aggfunc=np.mean, columns=['gender'],index=['year','month']).plot(kind='bar')
